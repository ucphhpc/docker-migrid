# %%
import sys
import numpy as np
import os

#LOCAL imports
from arcmodelling_IDMC import artificial_data_gen as adgen
from arcmodelling_IDMC import tools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-dec093e4328d> in <module>
#       4
#       5 #LOCAL imports
# ----> 6 from arcmodelling_IDMC import artificial_data_gen as adgen
#       7 from arcmodelling_IDMC import tools
#
# ~/repos/patches_workflow_dev/elise_dev/artificial_dataset_generation/arcmodelling_IDMC/artificial_data_gen.py in <module>
#       5 import itertools
#       6
# ----> 7 from arcmodelling_IDMC import model_functions as mf
#       8 from arcmodelling_IDMC import tools
#       9
#
# ~/repos/patches_workflow_dev/elise_dev/artificial_dataset_generation/arcmodelling_IDMC/model_functions.py in <module>
#       5 """
#       6 import numpy as np
# ----> 7 import torch
#       8 import math
#       9 # import torch.nn.functional as F
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# # 1. Create volume with center distances

# %% [markdown]
# ## Default parameters

# %%
N=100

# %% [markdown]
# ## Generate data

# %%
centerdist_vol = adgen.generate_centerdist_vol(N)
# Out:
# Volume size: (100, 100, 100)
# Gives 1000000 voxels

# %% [markdown]
# ## (Plotting)

# %%
tools.plot_center_slices(centerdist_vol)

# %% [markdown]
# ## Save data

# %%
processed_data = 'centerdist_vol.npy'
np.save(processed_data), centerdist_vol)
